# %% [markdown]
# ### 读取数据

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original_data=pd.read_csv("penguins_size.csv")
original_data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ### 评估和清理数据

# %%
cleaned_data=original_data.copy()

# %%
cleaned_data.head(10)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
# 6  Adelie  Torgersen              38.9             17.8              181.0
# 7  Adelie  Torgersen              39.2             19.6              195.0
# 8  Adelie  Torgersen              34.1             18.1              193.0
# 9  Adelie  Torgersen              42.0             20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE
# 5       3650.0    MALE
# 6       3625.0  FEMALE
# 7       4675.0    MALE
# 8       3475.0     NaN
# 9       4250.0     NaN

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            220 non-null    object
#  1   island             220 non-null    object
#  2   culmen_length_mm   218 non-null    float64
#  3   culmen_depth_mm    218 non-null    float64
#  4   flipper_length_mm  218 non-null    float64
#  5   body_mass_g        218 non-null    float64
#  6   sex                211 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
cleaned_data['species']=cleaned_data['species'].astype("category")
cleaned_data['sex']=cleaned_data['sex'].astype("category")
cleaned_data['island']=cleaned_data['island'].astype("category")

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            220 non-null    category
#  1   island             220 non-null    category
#  2   culmen_length_mm   218 non-null    float64
#  3   culmen_depth_mm    218 non-null    float64
#  4   flipper_length_mm  218 non-null    float64
#  5   body_mass_g        218 non-null    float64
#  6   sex                211 non-null    category
# dtypes: category(3), float64(4)
# memory usage: 12.3 KB

# %%
cleaned_data.query("culmen_length_mm.isna()")
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 30      NaN        NaN               NaN              NaN                NaN
# 31      NaN        NaN               NaN              NaN                NaN
# 32      NaN        NaN               NaN              NaN                NaN
# 33      NaN        NaN               NaN              NaN                NaN
# ..      ...        ...               ...              ...                ...
# 216     NaN        NaN               NaN              NaN                NaN
# 217     NaN        NaN               NaN              NaN                NaN
# 218     NaN        NaN               NaN              NaN                NaN
# 219     NaN        NaN               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 30           NaN  NaN
# 31           NaN  NaN
# 32           NaN  NaN
# 33           NaN  NaN
# ..           ...  ...
# 216          NaN  NaN
# 217          NaN  NaN
# 218          NaN  NaN
# 219          NaN  NaN
# 339          NaN  NaN
#
# [126 rows x 7 columns]

# %%
cleaned_data.query("flipper_length_mm.isna()")
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 30      NaN        NaN               NaN              NaN                NaN
# 31      NaN        NaN               NaN              NaN                NaN
# 32      NaN        NaN               NaN              NaN                NaN
# 33      NaN        NaN               NaN              NaN                NaN
# ..      ...        ...               ...              ...                ...
# 216     NaN        NaN               NaN              NaN                NaN
# 217     NaN        NaN               NaN              NaN                NaN
# 218     NaN        NaN               NaN              NaN                NaN
# 219     NaN        NaN               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 30           NaN  NaN
# 31           NaN  NaN
# 32           NaN  NaN
# 33           NaN  NaN
# ..           ...  ...
# 216          NaN  NaN
# 217          NaN  NaN
# 218          NaN  NaN
# 219          NaN  NaN
# 339          NaN  NaN
#
# [126 rows x 7 columns]

# %%
cleaned_data.query("body_mass_g.isna()")
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 30      NaN        NaN               NaN              NaN                NaN
# 31      NaN        NaN               NaN              NaN                NaN
# 32      NaN        NaN               NaN              NaN                NaN
# 33      NaN        NaN               NaN              NaN                NaN
# ..      ...        ...               ...              ...                ...
# 216     NaN        NaN               NaN              NaN                NaN
# 217     NaN        NaN               NaN              NaN                NaN
# 218     NaN        NaN               NaN              NaN                NaN
# 219     NaN        NaN               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 30           NaN  NaN
# 31           NaN  NaN
# 32           NaN  NaN
# 33           NaN  NaN
# ..           ...  ...
# 216          NaN  NaN
# 217          NaN  NaN
# 218          NaN  NaN
# 219          NaN  NaN
# 339          NaN  NaN
#
# [126 rows x 7 columns]

# %%
cols_to_check = ['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex']

# %%
drop_indexes = cleaned_data[cleaned_data[cols_to_check].isnull().all(axis=1)].index

# %%
cleaned_data = cleaned_data.drop(drop_indexes)

# %%
cleaned_data.query("sex.isna()")
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 8    Adelie  Torgersen              34.1             18.1              193.0
# 9    Adelie  Torgersen              42.0             20.2              190.0
# 10   Adelie  Torgersen              37.8             17.1              186.0
# 11   Adelie  Torgersen              37.8             17.3              180.0
# 246  Gentoo     Biscoe              44.5             14.3              216.0
# 286  Gentoo     Biscoe              46.2             14.4              214.0
# 324  Gentoo     Biscoe              47.3             13.8              216.0
#
#      body_mass_g  sex
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# 11        3700.0  NaN
# 246       4100.0  NaN
# 286       4650.0  NaN
# 324       4725.0  NaN

# %%
cleaned_data["species"].value_counts()
# Out:
# species
# Gentoo    123
# Adelie     95
# Name: count, dtype: int64

# %%
cleaned_data["sex"].value_counts()
# Out:
# sex
# MALE      106
# FEMALE    104
# .           1
# Name: count, dtype: int64

# %%
cleaned_data['sex']=cleaned_data['sex'].replace(".",np.nan)

# %%
cleaned_data["sex"].value_counts()
# Out:
# sex
# MALE      106
# FEMALE    104
# Name: count, dtype: int64

# %%
cleaned_data.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        218.000000       218.000000         218.000000   218.000000
# mean          43.782110        16.472477         205.376147  4479.816514
# std            5.166705         2.030817          14.954486   835.467922
# min           33.500000        13.100000         172.000000  2850.000000
# 25%           39.525000        14.700000         191.000000  3800.000000
# 50%           44.450000        16.100000         210.000000  4587.500000
# 75%           47.675000        18.075000         217.000000  5137.500000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# ### 可视化

# %%
# 设置图表色盘为“pastel”
sns.set_palette("pastel")

# %%
cleaned_data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [218 rows x 7 columns]

# %%
species_count=cleaned_data["species"].value_counts()
plt.pie(species_count,autopct='%.0f%%',labels=species_count.index)
plt.show()

# %%
island_count=cleaned_data["island"].value_counts()
plt.pie(island_count,autopct='%.0f%%',labels=island_count.index)
plt.show()

# %%
sex_count=cleaned_data["sex"].value_counts()
plt.pie(sex_count,autopct='%.0f%%',labels=sex_count.index)
plt.show()

# %%
sns.countplot(cleaned_data,x="island",hue="species")
plt.show()

# %%
sns.countplot(cleaned_data,x="island",hue="sex")
plt.show()

# %%
sns.pairplot(cleaned_data)
plt.show()

# %%
sns.pairplot(cleaned_data,hue="species")
plt.show()

# %%
sns.pairplot(cleaned_data,hue="species",kind='reg',plot_kws={'scatter_kws':{'alpha':0.3}})
plt.show()

# %%
sns.pairplot(cleaned_data,hue="sex")
plt.show()
